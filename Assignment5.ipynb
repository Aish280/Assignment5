# %%
# 1)python program to find Area of circle using math function
import math
def area_of_circle(r): 
    a = r**2 * math.pi
    return a

r = float(input("Enter the radius of the circle: "))
print("Area of circle is", area_of_circle(r))
# Out:
# Enter the radius of the circle: 4
# Area of circle is 50.26548245743669

# %%
# 2)python program to find area of regular polygon using math function
import math
if __name__=="__main__":
      num_sides = int(input("Enter the number of sides: "))
side_length = float(input("Enter the side: "))
def polygon_area(n_sides, length):
            area = (n_sides * (length ** 2)) / (4 * math.tan((math.pi) / n_sides))
            print(area)

polygon_area(num_sides, side_length)
# Out:
# Enter the number of sides: 5
# Enter the side: 2
# 6.881909602355868

# %%
# 3)python program to find Area of segment of circle formula using math function
import math
diamStr=input("Enter the length of the diameter:   ")
d=int(diamStr)
chordStr = input( " Enter the chord length:          ")
chord = int(chordStr)
radius = (d/2)
theta = math.acos((radius**2 + radius**2 - chord**2)/(2*radius**2))
area = 1/2 * (theta - math.sin(theta)) * radius**2
print("The area of segment of circle is ",area)
# Out:
# Enter the length of the diameter:   20
#  Enter the chord length:          10
# The area of segment of circle is  9.058607370607957

# %%
# 4)python program to shuffle the  given list 
import random
test_list=[100,1,2,3,30,40,"hai","hello"]
print("The orginal list is:"+ str(test_list))
random.shuffle(test_list)
print("The shuffled list is:"+ str(test_list))
# Out:
# The orginal list is:[100, 1, 2, 3, 30, 40, 'hai', 'hello']
# The shuffled list is:['hai', 30, 3, 100, 40, 'hello', 2, 1]

# %%
# 5)python program to generate random numbers between 1,10000 and difference between each random number is 50
import random
for i in range(1,10000,50):
    print(i)
print("A random number from range 1 and 10000 is:",end="")
print(random.randrange(1,10000,50))
# Out:
# 1
# 51
# 101
# 151
# 201
# 251
# 301
# 351
# 401
# 451
# 501
# 551
# 601
# 651
# 701
# 751
# 801
# 851
# 901
# 951
# 1001
# 1051
# 1101
# 1151
# 1201
# 1251
# 1301
# 1351
# 1401
# 1451
# 1501
# 1551
# 1601
# 1651
# 1701
# 1751
# 1801
# 1851
# 1901
# 1951
# 2001
# 2051
# 2101
# 2151
# 2201
# 2251
# 2301
# 2351
# 2401
# 2451
# 2501
# 2551
# 2601
# 2651
# 2701
# 2751
# 2801
# 2851
# 2901
# 2951
# 3001
# 3051
# 3101
# 3151
# 3201
# 3251
# 3301
# 3351
# 3401
# 3451
# 3501
# 3551
# 3601
# 3651
# 3701
# 3751
# 3801
# 3851
# 3901
# 3951
# 4001
# 4051
# 4101
# 4151
# 4201
# 4251
# 4301
# 4351
# 4401
# 4451
# 4501
# 4551
# 4601
# 4651
# 4701
# 4751
# 4801
# 4851
# 4901
# 4951
# 5001
# 5051
# 5101
# 5151
# 5201
# 5251
# 5301
# 5351
# 5401
# 5451
# 5501
# 5551
# 5601
# 5651
# 5701
# 5751
# 5801
# 5851
# 5901
# 5951
# 6001
# 6051
# 6101
# 6151
# 6201
# 6251
# 6301
# 6351
# 6401
# 6451
# 6501
# 6551
# 6601
# 6651
# 6701
# 6751
# 6801
# 6851
# 6901
# 6951
# 7001
# 7051
# 7101
# 7151
# 7201
# 7251
# 7301
# 7351
# 7401
# 7451
# 7501
# 7551
# 7601
# 7651
# 7701
# 7751
# 7801
# 7851
# 7901
# 7951
# 8001
# 8051
# 8101
# 8151
# 8201
# 8251
# 8301
# 8351
# 8401
# 8451
# 8501
# 8551
# 8601
# 8651
# 8701
# 8751
# 8801
# 8851
# 8901
# 8951
# 9001
# 9051
# 9101
# 9151
# 9201
# 9251
# 9301
# 9351
# 9401
# 9451
# 9501
# 9551
# 9601
# 9651
# 9701
# 9751
# 9801
# 9851
# 9901
# 9951
# A random number from range 1 and 10000 is:8901

# %%
# 6)python program using math module
import math
print(math.sin(60))
print(math.cos(180))
print(math.tan(90))
print(math.sinh(0.8660254037844386))
print(math.pow(5,8))
print(math.sqrt(400))
print(math.pow(5,2.71828))
print(math.log2(1024))
print(math.log10(1024))
print(math.ceil(23.56))
print(math.floor(23.56))
# Out:
# -0.3048106211022167
# -0.5984600690578581
# -1.995200412208242
# 0.978411324591025
# 390625.0
# 20.0
# 79.432125413701
# 10.0
# 3.010299956639812
# 24
# 23
